# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
file_path = 'C://Projects_python//Project//Case Study//Downloads//Case Study 2 - Credit Card Case Study//'

# %%
file_name = 'Customer Acqusition.csv'

# %%
customer_acq = pd.read_csv(file_path+file_name)

customer_acq.head(1)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed

# %%
customer_acq.drop(columns= ['No'], inplace= True)

customer_acq.head()
# Out:
#   Customer  Age       City   Product     Limit Company        Segment
# 0       A1   76  BANGALORE      Gold  500000.0      C1  Self Employed
# 1       A2   71   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2       A3   34     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3       A4   47     BOMBAY  Platimum   10001.0      C4           Govt
# 4       A5   56  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
file_name = 'Repayment.csv'

repayment = pd.read_csv(file_path+file_name)

# %%
file_name = 'spend.csv'

spend = pd.read_csv(file_path+file_name)

repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
repayment.drop(columns= ['Unnamed: 4','SL No:'],inplace= True)

repayment
# Out:
#      Customer      Month     Amount
# 0          A1  12-Jan-04  495414.75
# 1          A1   3-Jan-04  245899.02
# 2          A1  15-Jan-04  259490.06
# 3          A1  25-Jan-04  437555.12
# 4          A1  17-Jan-05  165972.88
# ...       ...        ...        ...
# 1518      NaN        NaN        NaN
# 1519      NaN        NaN        NaN
# 1520      NaN        NaN        NaN
# 1521      NaN        NaN        NaN
# 1522      NaN        NaN        NaN
#
# [1523 rows x 3 columns]

# %%
spend
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
spend.drop(columns= ['Sl No:'], inplace= True)

spend.head()
# Out:
#   Customer      Month       Type     Amount
# 0       A1  12-Jan-04  JEWELLERY  485470.80
# 1       A1   3-Jan-04      PETRO  410556.13
# 2       A1  15-Jan-04    CLOTHES   23740.46
# 3       A1  25-Jan-04       FOOD  484342.47
# 4       A1  17-Jan-05     CAMERA  369694.07

# %%
customer_acq.isna().sum()
# Out:
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
repayment.isna().sum()
# Out:
# Customer    23
# Month       23
# Amount      23
# dtype: int64

# %%
spend.isna().sum()
# Out:
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
repayment.dropna(inplace= True)

# %%
repayment.isna().sum()
# Out:
# Customer    0
# Month       0
# Amount      0
# dtype: int64

# %%
new_mean = customer_acq.Age.mean()

# %%
new_mean
# Out:
# 46.49

# %%
customer_acq.loc[customer_acq.Age < 18, :]
# Out:
#    Customer  Age        City   Product     Limit Company        Segment
# 13      A14   16   BANGALORE      Gold  500000.0     C14   Salaried_Pvt
# 40      A41   13      COCHIN  Platimum  500000.0     C23           Govt
# 62      A63   15   BANGALORE      Gold  500000.0     C25  Self Employed
# 67      A68   12  TRIVANDRUM    Silver  100000.0     C30  Self Employed
# 69      A70   16      BOMBAY  Platimum   10001.0     C32  Self Employed
# 89      A90   16      COCHIN      Gold  500000.0     C13           Govt

# %%
customer_acq.loc[customer_acq.Age < 18, 'Age'] = 46.49

# %%
customer_acq.Age.min()
# Out:
# 19.0

# %%
customer_acq.loc[:, :]
# Out:
#    Customer   Age        City   Product     Limit Company        Segment
# 0        A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1        A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2        A3  34.0      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3        A4  47.0      BOMBAY  Platimum   10001.0      C4           Govt
# 4        A5  56.0   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..      ...   ...         ...       ...       ...     ...            ...
# 95      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 7 columns]

# %%
# b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
# (customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
cust_spend = pd.merge(left= customer_acq, right= spend, left_on= 'Customer', right_on= 'Customer', how= 'inner')

# %%
cust_spend
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount
# ...

# %%
cust_spend.loc[(cust_spend.Limit < cust_spend.Amount),:]
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 18         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 19         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 20         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 21         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 22         A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# ...       ...   ...         ...       ...       ...     ...            ...
# 1486      A87  27.0    CALCUTTA    Silver  100003.0     C10           Govt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month          Type     Amount
# ...

# %%
cust_spend.loc[cust_spend["Amount"] > cust_spend["Limit"],"Amount"] = (0.5 * cust_spend["Limit"])

# %%
cust_spend.loc[(cust_spend.Limit < cust_spend.Amount),:]
# Out:
# Empty DataFrame
# Columns: [Customer, Age, City, Product, Limit, Company, Segment, Month, Type, Amount]
# Index: []

# %%
# c. Incase the repayment amount is more than the limit, replace the repayment with the
# limit.

# %%
repayment.head()
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02
# 2       A1  15-Jan-04  259490.06
# 3       A1  25-Jan-04  437555.12
# 4       A1  17-Jan-05  165972.88

# %%
customer_acq.head()
# Out:
#   Customer   Age       City   Product     Limit Company        Segment
# 0       A1  76.0  BANGALORE      Gold  500000.0      C1  Self Employed
# 1       A2  71.0   CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2       A3  34.0     COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3       A4  47.0     BOMBAY  Platimum   10001.0      C4           Govt
# 4       A5  56.0  BANGALORE  Platimum   10002.0      C5  Normal Salary

# %%
cust_repayment = pd.merge(left = customer_acq, right= repayment, left_on= 'Customer', right_on= 'Customer', how= 'inner')

# %%
cust_repayment.loc[(cust_repayment.Limit < cust_repayment.Amount),'Amount']
# Out:
# 18      185955.07
# 19      412783.34
# 20      148038.67
# 21      179144.68
# 23      381635.66
#           ...
# 1486    462283.02
# 1495    310992.30
# 1496    121874.90
# 1497    337815.57
# 1498     25682.73
# Name: Amount, Length: 600, dtype: float64

# %%
cust_repayment.loc[(cust_repayment.Limit < cust_repayment.Amount),'Amount'] = cust_repayment.Limit

# %%
cust_repayment.loc[(cust_repayment.Limit < cust_repayment.Amount),:]
# Out:
# Empty DataFrame
# Columns: [Customer, Age, City, Product, Limit, Company, Segment, Month, Amount]
# Index: []

# %%
# 2. From the above dataset create the following summaries:

# %%
# a. How many distinct customers exist?

# %%
cust_repayment.Customer.nunique()
# Out:
# 100

# %%
# There are 100 unique customers

# %%
# b. How many distinct categories exist?

# %%
dist_cat = customer_acq.groupby('Segment').agg(Number = ('Segment', pd.Series.nunique))

# %%
dist_cat.Number.sum()
# Out:
# 5

# %%
# There are total of 5 distinct categories.

# %%
# c. What is the average monthly spend by customers?

# %%
spend.dtypes
# Out:
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
spend.head()
# Out:
#   Customer      Month       Type     Amount
# 0       A1  12-Jan-04  JEWELLERY  485470.80
# 1       A1   3-Jan-04      PETRO  410556.13
# 2       A1  15-Jan-04    CLOTHES   23740.46
# 3       A1  25-Jan-04       FOOD  484342.47
# 4       A1  17-Jan-05     CAMERA  369694.07

# %%
spend.Month = pd.to_datetime(spend['Month'],format="%d-%b-%y")

# %%
spend.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Type                object
# Amount             float64
# dtype: object

# %%
spend['date_month'] =spend.Month
spend['date_year'] = spend.Month

# %%
spend
# Out:
#      Customer      Month        Type     Amount date_month  date_year
# 0          A1 2004-01-12   JEWELLERY  485470.80 2004-01-12 2004-01-12
# 1          A1 2004-01-03       PETRO  410556.13 2004-01-03 2004-01-03
# 2          A1 2004-01-15     CLOTHES   23740.46 2004-01-15 2004-01-15
# 3          A1 2004-01-25        FOOD  484342.47 2004-01-25 2004-01-25
# 4          A1 2005-01-17      CAMERA  369694.07 2005-01-17 2005-01-17
# ...       ...        ...         ...        ...        ...        ...
# 1495      A67 2006-02-04  BUS TICKET  356872.73 2006-02-04 2006-02-04
# 1496      A68 2006-03-25  BUS TICKET  204971.10 2006-03-25 2006-03-25
# 1497      A69 2006-03-31  BUS TICKET   50449.44 2006-03-31 2006-03-31
# 1498      A70 2006-03-23  BUS TICKET   80593.94 2006-03-23 2006-03-23
# 1499      A71 2006-03-24  BUS TICKET  194447.62 2006-03-24 2006-03-24
#
# [1500 rows x 6 columns]

# %%
spend['Monthly'] = spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
spend['Yearly'] = spend['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
spend
# Out:
#      Customer      Month        Type     Amount date_month  date_year  \
# 0          A1 2004-01-12   JEWELLERY  485470.80 2004-01-12 2004-01-12
# 1          A1 2004-01-03       PETRO  410556.13 2004-01-03 2004-01-03
# 2          A1 2004-01-15     CLOTHES   23740.46 2004-01-15 2004-01-15
# 3          A1 2004-01-25        FOOD  484342.47 2004-01-25 2004-01-25
# 4          A1 2005-01-17      CAMERA  369694.07 2005-01-17 2005-01-17
# ...       ...        ...         ...        ...        ...        ...
# 1495      A67 2006-02-04  BUS TICKET  356872.73 2006-02-04 2006-02-04
# 1496      A68 2006-03-25  BUS TICKET  204971.10 2006-03-25 2006-03-25
# 1497      A69 2006-03-31  BUS TICKET   50449.44 2006-03-31 2006-03-31
# 1498      A70 2006-03-23  BUS TICKET   80593.94 2006-03-23 2006-03-23
# 1499      A71 2006-03-24  BUS TICKET  194447.62 2006-03-24 2006-03-24
#
#        Monthly Yearly
# 0      January   2004
# 1      January   2004
# 2      January   2004
# 3      January   2004
# ...

# %%
monthwise_grouping = spend.groupby(by = ['Yearly','Monthly']).agg(average_monthly_spendss = ('Amount', np.mean))

# %%
monthwise_grouping
# Out:
#                   average_monthly_spendss
# Yearly Monthly
# 2004   April                235272.037143
#        February             221215.270000
#        January              251712.068664
#        March                232146.119286
#        May                  217539.236429
#        November             270486.397857
#        September            310923.383571
# 2005   April                252181.326429
#        August               233734.634286
#        December             147503.060000
#        February             229802.279821
#        January              292741.372857
#        July                 229116.663571
#        June                 262688.112857
#        May                  245696.515429
#        November             286143.322857
#        October              194568.640714
#        September            188666.202143
# 2006   April                232468.967553
#        August               240699.717143
#        December             270470.980714
# ...

# %%
monthwise_grouping.average_monthly_spendss.round(2)
# Out:
# Yearly  Monthly
# 2004    April        235272.04
#         February     221215.27
#         January      251712.07
#         March        232146.12
#         May          217539.24
#         November     270486.40
#         September    310923.38
# 2005    April        252181.33
#         August       233734.63
#         December     147503.06
#         February     229802.28
#         January      292741.37
#         July         229116.66
#         June         262688.11
#         May          245696.52
#         November     286143.32
#         October      194568.64
#         September    188666.20
# 2006    April        232468.97
#         August       240699.72
#         December     270470.98
#         February     253858.26
#         January      282058.01
#         July         287505.10
#         June         177252.39
#         March        247166.08
#         May          236162.74
#         November     182841.29
#         October      236136.34
# ...

# %%
# d. What is the average monthly repayment by customers?

# %%
repayment.head()
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02
# 2       A1  15-Jan-04  259490.06
# 3       A1  25-Jan-04  437555.12
# 4       A1  17-Jan-05  165972.88

# %%
repayment['Month'] = pd.to_datetime(repayment.Month, format='%d-%b-%y')

# %%
repayment['monthly'] = repayment.Month.apply(lambda x:pd.Timestamp.strftime(x, format='%B'))
repayment['yearly'] = repayment.Month.apply(lambda x:pd.Timestamp.strftime(x, format='%Y'))

# %%
repayment
# Out:
#      Customer      Month     Amount    monthly yearly
# 0          A1 2004-01-12  495414.75    January   2004
# 1          A1 2004-01-03  245899.02    January   2004
# 2          A1 2004-01-15  259490.06    January   2004
# 3          A1 2004-01-25  437555.12    January   2004
# 4          A1 2005-01-17  165972.88    January   2005
# ...       ...        ...        ...        ...    ...
# 1495      A67 2005-05-09   55638.77        May   2005
# 1496      A68 2006-05-10  319836.49        May   2006
# 1497      A69 2006-07-11  247628.45       July   2006
# 1498      A70 2005-08-12  454016.51     August   2005
# 1499      A71 2004-09-13   56286.33  September   2004
#
# [1500 rows x 5 columns]

# %%
repayment_group = repayment.groupby(by = ['yearly','monthly']).agg(Average_repayment = ('Amount', np.mean))

# %%
repayment_group.round(2)
# Out:
#                   Average_repayment
# yearly monthly
# 2004   April              259141.68
#        February           256702.63
#        January            243489.65
#        March              252585.28
#        May                226162.72
#        November           209592.24
#        September          184487.85
# 2005   April              212688.63
#        August             264430.92
#        December           320379.34
#        February           238829.27
#        January            240548.10
#        July               239871.48
#        June               210199.82
#        May                263207.37
#        November           256695.12
#        October            219849.96
#        September          247700.17
# 2006   April              275472.25
#        August             224143.99
#        December           252736.57
#        February           284489.57
#        January            293475.39
#        July               257936.38
# ...

# %%
# e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month
# (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment
# – Monthly spend. Interest is earned only on positive profits and not on negative amounts)

# %%
cust_spend.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13
# 2  15-Jan-04    CLOTHES   23740.46
# 3  25-Jan-04       FOOD  484342.47
# 4  17-Jan-05     CAMERA  369694.07

# %%
repayment.head()
# Out:
#   Customer      Month     Amount  monthly yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004
# 2       A1 2004-01-15  259490.06  January   2004
# 3       A1 2004-01-25  437555.12  January   2004
# 4       A1 2005-01-17  165972.88  January   2005

# %%
cust_spend_repay = pd.merge(left = cust_spend, right = repayment, left_on= 'Customer', right_on= 'Customer', how = 'inner')

# %%
cust_spend_repay.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#      Month_x       Type  Amount_x    Month_y   Amount_y  monthly yearly
# 0  12-Jan-04  JEWELLERY  485470.8 2004-01-12  495414.75  January   2004
# 1  12-Jan-04  JEWELLERY  485470.8 2004-01-03  245899.02  January   2004
# 2  12-Jan-04  JEWELLERY  485470.8 2004-01-15  259490.06  January   2004
# 3  12-Jan-04  JEWELLERY  485470.8 2004-01-25  437555.12  January   2004
# 4  12-Jan-04  JEWELLERY  485470.8 2005-01-17  165972.88  January   2005

# %%
cust_spend_repay.rename(columns= {'Amount_x':'spend_amount', 'Amount_y':'Repayment_amount', 'Month_x':'spend_date', 'Month_y':'Repayment_date'}, inplace= True)

# %%
cust_spend_repay
# Out:
#       Customer   Age        City   Product     Limit Company        Segment  \
# 0           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...        ...   ...         ...       ...       ...     ...            ...
# 37279      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 37280      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 37281      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 37282      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 37283     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
cust_spend_repay['Profit'] = cust_spend_repay['Repayment_amount'] - cust_spend_repay['spend_amount']

# %%
cust_spend_repay.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#   spend_date       Type  spend_amount Repayment_date  Repayment_amount  \
# 0  12-Jan-04  JEWELLERY      485470.8     2004-01-12         495414.75
# 1  12-Jan-04  JEWELLERY      485470.8     2004-01-03         245899.02
# 2  12-Jan-04  JEWELLERY      485470.8     2004-01-15         259490.06
# 3  12-Jan-04  JEWELLERY      485470.8     2004-01-25         437555.12
# 4  12-Jan-04  JEWELLERY      485470.8     2005-01-17         165972.88
#
#    monthly yearly     Profit
# 0  January   2004    9943.95
# 1  January   2004 -239571.78
# 2  January   2004 -225980.74
# ...

# %%
cust_spend_repay.Profit = cust_spend_repay.Profit*1.029

# %%
cust_spend_repay_filter = cust_spend_repay.loc[cust_spend_repay.Profit >0,:]

# %%
cust_spend_repay_filter
# Out:
#       Customer   Age        City   Product     Limit Company        Segment  \
# 0           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 18          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 21          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 33          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 34          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...        ...   ...         ...       ...       ...     ...            ...
# 37279      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 37280      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 37281      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 37282      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 37283     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
cust_spend_repay_filter.groupby(by = ['yearly','monthly']).agg(Profit = ('Profit', np.mean))
# Out:
#                          Profit
# yearly monthly
# 2004   April      207532.317193
#        February   262204.188784
#        January    206406.940470
#        March      212305.182918
#        May        200778.436695
#        November   189615.285596
#        September  202889.184997
# 2005   April      187213.250526
#        August     244355.131649
#        December   295742.310670
#        February   197707.426925
#        January    194911.416694
#        July       174552.218010
#        June       207828.919104
#        May        210782.576516
#        November   209598.052554
#        October    145940.927054
#        September  275981.920853
# 2006   April      236595.352454
#        August     162142.671952
#        December   159270.602052
#        February   222071.099875
#        January    225325.411001
#        July       203406.954527
#        June       209746.174904
#        March      210676.762368
#        May        235190.414871
# ...

# %%
# f. What are the top 5 product types?

# %%
spend.head()
# Out:
#   Customer      Month       Type     Amount date_month  date_year  Monthly  \
# 0       A1 2004-01-12  JEWELLERY  485470.80 2004-01-12 2004-01-12  January
# 1       A1 2004-01-03      PETRO  410556.13 2004-01-03 2004-01-03  January
# 2       A1 2004-01-15    CLOTHES   23740.46 2004-01-15 2004-01-15  January
# 3       A1 2004-01-25       FOOD  484342.47 2004-01-25 2004-01-25  January
# 4       A1 2005-01-17     CAMERA  369694.07 2005-01-17 2005-01-17  January
#
#   Yearly
# 0   2004
# 1   2004
# 2   2004
# 3   2004
# 4   2005

# %%
spend['Type'].value_counts().head()
# Out:
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: Type, dtype: int64

# %%
# These are the top 5 categories on basis of count pf purchase

# %%
Top_five_spends = spend[['Type', 'Amount']]

# %%
Top_five_spends.groupby(by = 'Type').agg(np.sum).head()
# Out:
#                  Amount
# Type
# AIR TICKET  32955445.42
# AUTO         8008084.04
# BIKE        11551105.59
# BUS TICKET  24554787.97
# CAMERA      41481571.96

# %%
# These are the top 5 categories based on the amount spent

# %%
# g. Which city is having maximum spend?

# %%
cust_spend_repay
# Out:
#       Customer   Age        City   Product     Limit Company        Segment  \
# 0           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...        ...   ...         ...       ...       ...     ...            ...
# 37279      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 37280      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 37281      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 37282      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 37283     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
cust_spend_repay.groupby(by = 'City').agg(Total_spend =('spend_amount', np.sum)).sort_values(by= 'Total_spend',ascending=False)
# Out:
#              Total_spend
# City
# COCHIN      1.175903e+09
# CALCUTTA    1.114270e+09
# BANGALORE   1.081315e+09
# BOMBAY      7.597765e+08
# CHENNAI     5.748714e+08
# TRIVANDRUM  4.353974e+08
# PATNA       3.434695e+08
# DELHI       2.629844e+08

# %%
# Cochin has the maximum spends

# %%
# h. Which age group is spending more money?

# %%
cust_spend_repay['age_Category'] = pd.cut(cust_spend_repay['Age'],bins= np.arange(15,91,15), labels= ['15-30', '30-45', '45-60', '60-75', '75-90'])

# %%
cust_spend_repay
# Out:
#       Customer   Age        City   Product     Limit Company        Segment  \
# 0           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4           A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...        ...   ...         ...       ...       ...     ...            ...
# 37279      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 37280      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 37281      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 37282      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 37283     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# ...

# %%
cust_spend_repay.groupby('age_Category').agg({'spend_amount': np.sum}).sort_values(by = 'spend_amount', ascending= False)
# Out:
#               spend_amount
# age_Category
# 45-60         1.776658e+09
# 15-30         1.585074e+09
# 30-45         1.400845e+09
# 60-75         5.485165e+08
# 75-90         4.368940e+08

# %%
# people with age 45 to 60 spend the most

# %%
# i. Who are the top 10 customers in terms of repayment?

# %%
repayment.head()
# Out:
#   Customer      Month     Amount  monthly yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004
# 2       A1 2004-01-15  259490.06  January   2004
# 3       A1 2004-01-25  437555.12  January   2004
# 4       A1 2005-01-17  165972.88  January   2005

# %%
cust_repay = repayment.groupby(by = 'Customer').agg({'Amount':np.sum})

# %%
cust_repay.head(10)
# Out:
#               Amount
# Customer
# A1        4753691.67
# A10       3695647.52
# A100        69551.19
# A11       5310934.03
# A12       8334760.16
# A13       9572000.66
# A14       7943268.63
# A15       5555412.83
# A16       4259827.95
# A17       5284374.99

# %%
cust_repay.sort_values(by = 'Amount', ascending= False).head(10)
# Out:
#                Amount
# Customer
# A61       10539142.91
# A60        9876290.74
# A13        9572000.66
# A22        9372561.68
# A21        9056336.15
# A43        8489871.46
# A45        8448334.87
# A12        8334760.16
# A48        8292416.75
# A14        7943268.63

# %%
# these are the top 10 customers in terms of repayment

# %%
'''4. Create graphs for
a. Monthly comparison of total spends, city wise
b. Comparison of yearly spend on air tickets
c. Comparison of monthly spend for each product (look for any seasonality
that exists in terms of spend)'''
# Out:
# '4. Create graphs for\na. Monthly comparison of total spends, city wise\nb. Comparison of yearly spend on air tickets\nc. Comparison of monthly spend for each product (look for any seasonality\nthat exists in terms of spend)'

# %%
# a. Monthly comparison of total spends, city wise

# %%
cust_spend_repay.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#   spend_date       Type  spend_amount Repayment_date  Repayment_amount  \
# 0  12-Jan-04  JEWELLERY      485470.8     2004-01-12         495414.75
# 1  12-Jan-04  JEWELLERY      485470.8     2004-01-03         245899.02
# 2  12-Jan-04  JEWELLERY      485470.8     2004-01-15         259490.06
# 3  12-Jan-04  JEWELLERY      485470.8     2004-01-25         437555.12
# 4  12-Jan-04  JEWELLERY      485470.8     2005-01-17         165972.88
#
#    monthly yearly        Profit age_Category
# 0  January   2004   10232.32455        75-90
# ...

# %%
spend_city_graph = cust_spend_repay.groupby(by = ['City','monthly']).agg(Total_spend =('spend_amount', np.sum)).sort_values(by= 'City',ascending=False)

# %%
spend_city_graph
# Out:
#                        Total_spend
# City       monthly
# TRIVANDRUM November   4.091412e+07
#            May        1.003189e+08
#            March      6.279151e+07
#            June       8.215555e+06
#            July       2.068790e+07
# ...                            ...
# BANGALORE  May        1.879520e+08
#            November   6.380411e+07
#            October    9.418636e+06
#            September  3.180167e+07
#            April      7.866440e+07
#
# [93 rows x 1 columns]

# %%
spend_city_graph = spend_city_graph.reset_index().groupby(['City', 'monthly'])['Total_spend'].aggregate(np.sum).unstack()
spend_city_graph
# Out:
# monthly            April       August     December      February  \
# City
# BANGALORE   7.866440e+07  39239529.68   9320340.09  1.946078e+08
# BOMBAY      6.596563e+07  17277458.46   5876216.35  9.924008e+07
# CALCUTTA    1.079139e+08  61034500.71   9216899.60  1.597549e+08
# CHENNAI     3.554682e+07   6948235.19  20407767.29  7.427967e+07
# COCHIN      1.679990e+08  42182713.16  12332130.60  1.568157e+08
# DELHI       2.684413e+07  14686321.25  10241379.92  2.637315e+07
# PATNA       3.638568e+07   6876389.81   6876389.81  6.010446e+07
# TRIVANDRUM  1.676833e+07   6391189.56  15067473.89  5.950345e+07
#
# monthly          January         July         June         March  \
# City
# BANGALORE   2.131835e+08  37952501.99  59054565.28  1.563158e+08
# BOMBAY      1.663625e+08  34675827.31  28955688.14  1.199354e+08
# CALCUTTA    2.630035e+08  29297412.73  28801390.63  1.579530e+08
# CHENNAI     1.269797e+08   6948235.19  25618842.43  8.537481e+07
# ...

# %%
spend_city_graph.index
# Out:
# Index(['BANGALORE', 'BOMBAY', 'CALCUTTA', 'CHENNAI', 'COCHIN', 'DELHI',
#        'PATNA', 'TRIVANDRUM'],
#       dtype='object', name='City')

# %%
spend_city_graph.columns
# Out:
# Index(['April', 'August', 'December', 'February', 'January', 'July', 'June',
#        'March', 'May', 'November', 'October', 'September'],
#       dtype='object', name='monthly')

# %%
# sns.barplot(x = spend_city_graph['City'], y = spend_city_graph['Total_spend'])
spend_city_graph.plot(kind = 'bar')
# plt.plot(spend_city_graph)
plt.xticks(rotation = 90)
plt.figure(figsize=(18,6))
plt.show()

# %%
# b. Comparison of yearly spend on air tickets

# %%
spend
# Out:
#      Customer      Month        Type     Amount date_month  date_year  \
# 0          A1 2004-01-12   JEWELLERY  485470.80 2004-01-12 2004-01-12
# 1          A1 2004-01-03       PETRO  410556.13 2004-01-03 2004-01-03
# 2          A1 2004-01-15     CLOTHES   23740.46 2004-01-15 2004-01-15
# 3          A1 2004-01-25        FOOD  484342.47 2004-01-25 2004-01-25
# 4          A1 2005-01-17      CAMERA  369694.07 2005-01-17 2005-01-17
# ...       ...        ...         ...        ...        ...        ...
# 1495      A67 2006-02-04  BUS TICKET  356872.73 2006-02-04 2006-02-04
# 1496      A68 2006-03-25  BUS TICKET  204971.10 2006-03-25 2006-03-25
# 1497      A69 2006-03-31  BUS TICKET   50449.44 2006-03-31 2006-03-31
# 1498      A70 2006-03-23  BUS TICKET   80593.94 2006-03-23 2006-03-23
# 1499      A71 2006-03-24  BUS TICKET  194447.62 2006-03-24 2006-03-24
#
#        Monthly Yearly
# 0      January   2004
# 1      January   2004
# 2      January   2004
# 3      January   2004
# ...

# %%
spend.Type.unique()
# Out:
# array(['JEWELLERY', 'PETRO', 'CLOTHES', 'FOOD', 'CAMERA', 'SANDALS',
#        'CAR', 'BIKE', 'AUTO', 'SHOPPING', 'AIR TICKET', 'BUS TICKET',
#        'TRAIN TICKET', 'RENTAL', 'MOVIE TICKET'], dtype=object)

# %%
Yearly_spend_graph = spend[['Yearly','Amount']]

# %%
Yearly_spend_graph
# Out:
#      Yearly     Amount
# 0      2004  485470.80
# 1      2004  410556.13
# 2      2004   23740.46
# 3      2004  484342.47
# 4      2005  369694.07
# ...     ...        ...
# 1495   2006  356872.73
# 1496   2006  204971.10
# 1497   2006   50449.44
# 1498   2006   80593.94
# 1499   2006  194447.62
#
# [1500 rows x 2 columns]

# %%
tab_spend_year = Yearly_spend_graph.groupby(by = 'Yearly').agg(Amount = ('Amount', np.sum))

# %%
tab_spend_year.reset_index(inplace = True)

# %%
tab_spend_year
# Out:
#   Yearly        Amount
# 0   2004  1.044926e+08
# 1   2005  1.284956e+08
# 2   2006  1.316559e+08

# %%
sns.barplot(x = tab_spend_year['Yearly'], y = tab_spend_year['Amount'])
plt.show()

# %%
# c. Comparison of monthly spend for each product

# %%
spend.head()
# Out:
#   Customer      Month       Type     Amount date_month  date_year  Monthly  \
# 0       A1 2004-01-12  JEWELLERY  485470.80 2004-01-12 2004-01-12  January
# 1       A1 2004-01-03      PETRO  410556.13 2004-01-03 2004-01-03  January
# 2       A1 2004-01-15    CLOTHES   23740.46 2004-01-15 2004-01-15  January
# 3       A1 2004-01-25       FOOD  484342.47 2004-01-25 2004-01-25  January
# 4       A1 2005-01-17     CAMERA  369694.07 2005-01-17 2005-01-17  January
#
#   Yearly
# 0   2004
# 1   2004
# 2   2004
# 3   2004
# 4   2005

# %%
monthly_spends_graph = spend.groupby('Monthly').agg({'Amount':np.sum})

# %%
monthly_spends_graph
# Out:
#                 Amount
# Monthly
# April      35500777.13
# August      9914365.80
# December    5851636.57
# February   55462857.52
# January    89421175.61
# July       11257776.06
# June       13514434.15
# March      56885086.04
# May        50668174.93
# November   20924385.25
# October     6029869.66
# September   9213535.47

# %%
# monthly_spends_graph.reset_index(inplace= True)

# %%
# monthly_spends_graph

# %%
month_spends =['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
monthly_spends_graph = monthly_spends_graph.loc[month_spends, :]
monthly_spends_graph
# Out:
#                 Amount
# Monthly
# January    89421175.61
# February   55462857.52
# March      56885086.04
# April      35500777.13
# May        50668174.93
# June       13514434.15
# July       11257776.06
# August      9914365.80
# September   9213535.47
# October     6029869.66
# November   20924385.25
# December    5851636.57

# %%
monthly_spends_graph.reset_index(inplace= True)

# %%
sns.barplot(x= monthly_spends_graph.Monthly, y= monthly_spends_graph.Amount)
plt.title('Monthly spend amount')
plt.xticks(rotation = 45)
plt.show()

# %%
# The highest spends arein the month of January

# %%
'''5. Write user defined PYTHON function to perform the following analysis:
You need to find top 10 customers for each city in terms of their repayment amount by
different products and by different time periods i.e. year or month. The user should be able
to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the
function should automatically take these inputs while identifying the top 10 customers.'''
# Out:
# '5. Write user defined PYTHON function to perform the following analysis:\nYou need to find top 10 customers for each city in terms of their repayment amount by\ndifferent products and by different time periods i.e. year or month. The user should be able\nto specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the\nfunction should automatically take these inputs while identifying the top 10 customers.'

# %%
cust_repayment.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month     Amount
# 0  12-Jan-04  495414.75
# 1   3-Jan-04  245899.02
# 2  15-Jan-04  259490.06
# 3  25-Jan-04  437555.12
# 4  17-Jan-05  165972.88

# %%
cust_repayment['Month'] = pd.to_datetime(cust_repayment['Month'])

# %%
cust_repayment['Monthly'] = cust_repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
cust_repayment['Yearly'] = cust_repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))

# %%
def summary_report(product,timeperiod):
    print('Give the product name and timeperiod for which you want the data')
    if product.lower()=='gold' and timeperiod.lower()=='monthly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='gold' and timeperiod.lower()=='yearly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='monthly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='yearly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    if product.lower()=='platinum' and timeperiod.lower()=='monthly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='platinum' and timeperiod.lower()=='yearly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    return result

# %%
summary_report('gold','monthly')
# Out:
# Give the product name and timeperiod for which you want the data
# Monthly                           April     August   December    February  \
# Product City       Customer
# Gold    BANGALORE  A1         508949.16        NaN        NaN   781873.80
#                    A13        494392.40  873304.51        NaN  2049808.15
#                    A14        812582.20  198623.13  388821.96  1482923.34
#                    A30        425694.16        NaN        NaN  1321469.80
#                    A43        612541.80        NaN        NaN   763846.93
#                    A63              NaN        NaN        NaN         NaN
#                    A81              NaN        NaN        NaN         NaN
#                    A88              NaN        NaN        NaN         NaN
#                    A92        459105.69        NaN        NaN         NaN
#         COCHIN     A11        958466.08  332677.61        NaN  1069789.26
# ...
